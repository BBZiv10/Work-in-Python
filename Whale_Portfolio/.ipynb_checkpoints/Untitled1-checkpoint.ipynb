# %%
import pandas as pd
df = pd.DataFrame

whale_path = "whales_returns.csv"
whale_file = pd.read_csv(whale_path, header=None, skiprows=1)
column_names = ['date', 'soros', 'paulson', 'tiger', 'berkshire']        
whale_file.head()
whale_file.columns=column_names
whale_file.columns
# Out:
# Index(['date', 'soros', 'paulson', 'tiger', 'berkshire'], dtype='object')

# %%
whale_file.dropna()
# Out:
#             date     soros   paulson     tiger  berkshire
# 1     2015-03-03 -0.001266 -0.004981 -0.000496  -0.006569
# 2     2015-03-04  0.002230  0.003241 -0.002534   0.004213
# 3     2015-03-05  0.004016  0.004076  0.002355   0.006726
# 4     2015-03-06 -0.007905 -0.003574 -0.008481  -0.013098
# 5     2015-03-09  0.000582  0.004225  0.005843  -0.001652
# ...          ...       ...       ...       ...        ...
# 1055  2019-04-25 -0.000285 -0.001291 -0.005153   0.004848
# 1056  2019-04-26  0.008149  0.009162  0.012355   0.010434
# 1057  2019-04-29  0.001254  0.002719  0.006251   0.005223
# 1058  2019-04-30 -0.001295 -0.002211 -0.000259  -0.003702
# 1059  2019-05-01 -0.005847 -0.001341 -0.007936  -0.007833
#
# [1059 rows x 5 columns]

# %%
whale_file['soros'] = pd.to_numeric(whale_file['soros'], downcast="float")
whale_file['paulson'] = pd.to_numeric(whale_file['paulson'], downcast="float")
whale_file['tiger'] = pd.to_numeric(whale_file['tiger'], downcast="float")
whale_file['berkshire'] = pd.to_numeric(whale_file['berkshire'], downcast="float")
print(whale_file)
# Out:
#             date     soros   paulson     tiger  berkshire
# 0     2015-03-02       NaN       NaN       NaN        NaN
# 1     2015-03-03 -0.001266 -0.004981 -0.000496  -0.006569
# 2     2015-03-04  0.002230  0.003241 -0.002534   0.004213
# 3     2015-03-05  0.004016  0.004076  0.002355   0.006726
# 4     2015-03-06 -0.007905 -0.003574 -0.008481  -0.013098
# ...          ...       ...       ...       ...        ...
# 1055  2019-04-25 -0.000285 -0.001291 -0.005153   0.004848
# 1056  2019-04-26  0.008149  0.009162  0.012355   0.010434
# 1057  2019-04-29  0.001254  0.002719  0.006251   0.005223
# 1058  2019-04-30 -0.001295 -0.002211 -0.000259  -0.003702
# 1059  2019-05-01 -0.005847 -0.001341 -0.007936  -0.007833
#
# [1060 rows x 5 columns]

# %%
snp = pd.read_csv("sp500.csv")
snp["Close"] = snp["Close"].str.replace("$",'')
snp["Close"] = pd.to_numeric(snp["Close"], downcast="float")
previous_return = None 

for closing_price in snp["Close"]:
    print(closing_price)

print(snp)
# Out:
# <ipython-input-77-792d7546a04c>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   snp["Close"] = snp["Close"].str.replace("$",'')
# 2933.679931640625
# 2907.969970703125
# 2905.030029296875
# 2900.449951171875
# 2907.06005859375
# 2905.580078125
# 2907.409912109375
# 2888.320068359375
# 2888.2099609375
# 2878.199951171875
# 2895.77001953125
# 2892.739990234375
# 2879.389892578125
# 2873.39990234375
# 2867.239990234375
# 2867.18994140625
# 2834.39990234375
# 2815.43994140625
# 2805.3701171875
# 2818.4599609375
# 2798.360107421875
# 2800.7099609375
# 2854.8798828125
# 2824.22998046875
# 2832.570068359375
# 2832.93994140625
# 2822.47998046875
# 2808.47998046875
# 2810.919921875
# 2791.52001953125
# 2783.300048828125
# 2743.070068359375
# 2748.929931640625
# 2771.449951171875
# 2789.64990234375
# 2792.81005859375
# 2803.68994140625
# ...
